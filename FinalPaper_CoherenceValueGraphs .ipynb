# %%
import matplotlib.pyplot as plt

# Data from the table
topic = list(range(7))
iteration1 = [0.321582, 0.321323, 0.321006, 0.321173, 0.320939, 0.320810, 0.320885]
iteration2 = [0.378322483, 0.827499487, 0.430924069, 0.827499487, 0.346593962, 0.827499487, 0.827499487]
iteration3 = [0.66674105, 0.39064673, 0.66674105, 0.66674105, 0.4336867, 0.66674105, 0.36582895]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(topic, iteration1, marker='o', label='1st iteration (s=200, default parameters)')
plt.plot(topic, iteration2, marker='o', label='2nd iteration (s=385, improved training parameters)')
plt.plot(topic, iteration3, marker='o', label='3rd iteration (s=1972, improved training parameters)')

# Adding labels and title
plt.xlabel('Topic')
plt.ylabel('Coherence Score')
plt.title('LDP Coherence Score vs Topic for Different Iterations')
plt.legend()
plt.grid(True)
plt.xticks(topic)  # Ensure all topics are displayed on x-axis
plt.tight_layout()

# Display plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
topic = list(range(38))
iteration1 = [0.32158900, 0.30904022, 0.33253991, 0.27681661, 0.33370110, 0.30470254, 0.32009432,
              0.35522892, 0.34036993, 0.32034357, 0.32141587, 0.31315342, 0.37742434, 0.32919183,
              0.30194155, 0.32406232, 0.28075245, 0.29416703, 0.29371789, 0.24887322, 0.36090615,
              0.27910223, 0.28118665, 0.29476552, 0.36405859, 0.22312023, 0.30104352, 0.30140142,
              0.31289342, 0.34451057, 0.39280360, 0.34455985, 0.37850265, 0.33229397, 0.22703961,
              0.32158900, None, None]

iteration2 = [0.33640348, 0.33640348, 0.27515214, 0.28234077, 0.31732046, 0.33226346, 0.31918224,
              0.33455076, 0.32032993, 0.33691783, 0.27214106, 0.31036996, 0.27861806, 0.34067572,
              0.38221844, 0.33902581, 0.33064272, 0.32245783, 0.29819393, 0.2263735, 0.35053454,
              0.30109477, 0.32276842, 0.31615488, 0.34339287, 0.3191801, 0.31279899, 0.29914988,
              0.27487793, 0.4089477, 0.29375181, 0.29683283, 0.34686377, 0.29199312, 0.34823557,
              0.37526959, 0.33474749, 0.31153237]

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(topic, iteration1, marker='o', label='1st Iteration (s=385, default parameters)')
plt.plot(topic, iteration2, marker='o', label='2nd Iteration (s=1972, improved training parameters)')

# Adding labels and title
plt.xlabel('Topic')
plt.ylabel('Coherence Score')
plt.title('HDP Coherence Score vs Topic for Different Iterations')
plt.legend()
plt.grid(True)
plt.xticks(topic, rotation=90)  # Ensure all topics are displayed on x-axis
plt.tight_layout()

# Display plot
plt.show()
