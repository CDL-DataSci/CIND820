# %%
#Creating Initial Sample Size
import os
import shutil
import random

# Source and destination folders
source_folder = '/Users/cdlacey/TMU_DataScience/CIND820/Dataset'
destination_folder = '/Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample'

# Ensure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# List all files in the source folder
files = os.listdir(source_folder)

# Randomly select 25 files
selected_files = random.sample(files, 25)

# Copy selected files to the destination folder
for file_name in selected_files:
    source_file_path = os.path.join(source_folder, file_name)
    destination_file_path = os.path.join(destination_folder, file_name)
    shutil.copyfile(source_file_path, destination_file_path)
    print(f"Copying {file_name} to {destination_folder}")

print("Files copied successfully!")
# Out:
# Copying 20141121-HAN146-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20070509-HAN150-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20090514-HAN058-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20170502-HAN168-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20141104-HAN138-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20201019-HAN014-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20161114-HAN106-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20220404-HAN052-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20171103-HAN229-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20190201-HAN376-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# Copying 20140207-HAN044-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample
# ...

# %%
#Identify adequate sample size
import math

# Constants
Z = 1.96  # Z-score for 95% confidence level
p = 0.5   # Estimated proportion (use 0.5 for maximum sample size)
E = 0.05  # Margin of error (5%)

# Calculate sample size
n = (Z**2 * p * (1 - p)) / (E**2)

# Round up to the nearest whole number
sample_size = math.ceil(n)

print("Smallest sample size with 95% confidence:", sample_size)
# Out:
# Smallest sample size with 95% confidence: 385

# %%
#Creating Folder for Larger Sample Size
source_folder = '/Users/cdlacey/TMU_DataScience/CIND820/Dataset'
destination_folder = '/Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385'

if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

files = os.listdir(source_folder)

# Randomly select 385 files
selected_files = random.sample(files, 385)

# Copy selected files to the destination folder
for file_name in selected_files:
    source_file_path = os.path.join(source_folder, file_name)
    destination_file_path = os.path.join(destination_folder, file_name)
    shutil.copyfile(source_file_path, destination_file_path)
    print(f"Copying {file_name} to {destination_folder}")

print("Files copied successfully!")
# Out:
# Copying 20090303-HAN022-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20130509-HAN250-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20120424-HAN109-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20210125-HAN049-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20211216-HAN019-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20201119-HAN032-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20180327-HAN276-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20130328-HAN231-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20201126-HAN037-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# Copying 20191211-HAN005-E.pdf to /Users/cdlacey/TMU_DataScience/CIND820/Dataset_Sample_385
# ...
